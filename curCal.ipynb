# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
x = [
56232, 107,
43600, 74,
33500, 51,
25200, 33,
15150, 13,
12200, 8,
9750, 2,
0, -8,
-2100, -18,
-17800, -39,
-27200, -54,
-57000, -109,
-82300, -160,
-143500, -295,
-476500, -1100,
-524150, -1400]

dacValues = abs(array(x[::2]))
currents =  abs(array(x[1::2]))

# %%
close("all")
fitX = dacValues[11:-1]
fitY = currents[11:-1]
plot(dacValues, currents, "og", label="raw")
plot(fitX, fitY, "or", label="fit measured")
fit = np.polyfit(fitX,fitY,1)
fit_fn = np.poly1d(fit)
xFit = linspace(-100, 500000, 500 )
plot( xFit, fit_fn(xFit) )
display(gcf())

# %%
fit
# Out:
# array([  2.37812346e-03,  -3.54272857e+01])

# %%
1/2.37812346e-03
# Out:
# 420.499615272287
